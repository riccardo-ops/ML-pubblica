# %% [markdown]
# # 1 - Create

# %%
# prima di tutto importo pandas
import pandas as pd
# se scrivo pd. e premo tab, posso vedere tutti i metodi che ci sono in pandas

# %% [markdown]
# ## 1.1 Crea da un file csv

# %%
# mi sono scaricato un file csv che si chiama telco_churn.csv

# %%
df = pd.read_csv('telco_churn.csv') # ricordati di importare il documento csv nella stessa repository di jupiter

# %% [markdown]
# ## 1.2 Crea con un dizionario

# %%
dizionario = {'colonna1' : [1, 2, 3], 'colonna2' : [4, 5, 6], 'colonna3' : [7, 8, 9]}

# %%
dizdf = pd.DataFrame.from_dict(dizionario)

# %% [markdown]
# # 2 Read

# %% [markdown]
# ## 2.1 Lettura di base

# %%
df.head() # se non specifico tra parentesi il numero, di default ne vedo 5
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1            110.0
# 1                     26              161.6            123.0
# 2                      0              243.4            114.0
# 3                      0              299.4             71.0
# 4                      0              166.7            113.0
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4             99.0             16.78
# ...

# %%
df.tail()
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 3328                     36              156.2             77.0
# 3329                      0              231.1             57.0
# 3330                      0              180.8            109.0
# 3331                      0              213.8            105.0
# 3332                     25              234.4            113.0
#
#       Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# ...

# %%
dizdf.head()
# Out:
#    colonna1  colonna2  colonna3
# 0         1         4         7
# 1         2         5         8
# 2         3         6         9

# %% [markdown]
# ## 2.2 Visualizzare colonne e tipo di dati

# %%
# per vedere quali colonne ci sono in un dataframe mi serve l'attributo .columns
df.columns
# Out:
# Index(['State', 'Account length', 'Area code', 'International plan',
#        'Voice mail plan', 'Number vmail messages', 'Total day minutes',
#        'Total day calls', 'Total day charge', 'Total eve minutes',
#        'Total eve calls', 'Total eve charge', 'Total night minutes',
#        'Total night calls', 'Total night charge', 'Total intl minutes',
#        'Total intl calls', 'Total intl charge', 'Customer service calls',
#        'Churn'],
#       dtype='object')

# %%
# se volessi invece sapere che tipo di dato c'è as loro interno uso dtypes
df.dtypes
# Out:
# State                      object
# Account length              int64
# Area code                   int64
# International plan         object
# Voice mail plan            object
# Number vmail messages       int64
# Total day minutes         float64
# Total day calls           float64
# Total day charge          float64
# Total eve minutes         float64
# Total eve calls           float64
# Total eve charge          float64
# Total night minutes       float64
# Total night calls         float64
# Total night charge        float64
# Total intl minutes        float64
# Total intl calls            int64
# Total intl charge         float64
# Customer service calls    float64
# Churn                      object
# dtype: object

# %% [raw]
# Da notare che .columns e .dtypes sono due ATTRIBUTI, ovvero non mi richiede la parentesi la loro chiamata

# %% [markdown]
# ## 2.3 Summary Statistics

# %%
df.describe()
# Out:
#        Account length    Area code  Number vmail messages  Total day minutes  \
# count     3333.000000  3333.000000            3333.000000        3323.000000
# mean       101.064806   437.182418               8.099010         179.787150
# std         39.822106    42.371290              13.688365          54.419625
# min          1.000000   408.000000               0.000000           0.000000
# 25%         74.000000   408.000000               0.000000         143.700000
# 50%        101.000000   415.000000               0.000000         179.400000
# 75%        127.000000   510.000000              20.000000         216.500000
# max        243.000000   510.000000              51.000000         350.800000
#
#        Total day calls  Total day charge  Total eve minutes  Total eve calls  \
# count      3323.000000       3315.000000        3324.000000      3325.000000
# mean        100.456214         30.557831         201.033935       100.110677
# ...

# %%
# se volessi le statistiche di solo un tipo di dato, basta specificare quale
df.describe(include = 'object')
# Out:
#        State International plan Voice mail plan  Churn
# count   3333               3333            3333   3325
# unique    51                  2               2      2
# top       WV                 No              No  False
# freq     106               3010            2411   2842

# %%
df.describe(include = 'int64')
# Out:
#        Account length    Area code  Number vmail messages  Total intl calls
# count     3333.000000  3333.000000            3333.000000       3333.000000
# mean       101.064806   437.182418               8.099010          4.479448
# std         39.822106    42.371290              13.688365          2.461214
# min          1.000000   408.000000               0.000000          0.000000
# 25%         74.000000   408.000000               0.000000          3.000000
# 50%        101.000000   415.000000               0.000000          4.000000
# 75%        127.000000   510.000000              20.000000          6.000000
# max        243.000000   510.000000              51.000000         20.000000

# %% [markdown]
# ## 2.4 Filtering Columns

# %%
# come accedere ad una colonna?
# posso usarle come chiavi e scrivere:
df.State
# Out:
# 0       KS
# 1       OH
# 2       NJ
# 3       OH
# 4       OK
#         ..
# 3328    AZ
# 3329    WV
# 3330    RI
# 3331    CT
# 3332    TN
# Name: State, Length: 3333, dtype: object

# %%
# Se nel nome delle colonne invece ho uno spazio? Problema
df['Account length']
# Out:
# 0       128
# 1       107
# 2       137
# 3        84
# 4        75
#        ...
# 3328    192
# 3329     68
# 3330     28
# 3331    184
# 3332     74
# Name: Account length, Length: 3333, dtype: int64

# %%
# posso anche selezionare un array di colonne e non usa sola.
df[['Account length', 'Area code']]
# Out:
#       Account length  Area code
# 0                128        415
# 1                107        415
# 2                137        415
# 3                 84        408
# 4                 75        415
# ...              ...        ...
# 3328             192        415
# 3329              68        415
# 3330              28        510
# 3331             184        510
# 3332              74        415
#
# [3333 rows x 2 columns]

# %%
# se volessi vedere quali valori (presenti almeno una volta):
df.State.unique()
# Out:
# array(['KS', 'OH', 'NJ', 'OK', 'AL', 'MA', 'MO', 'LA', 'WV', 'IN', 'RI',
#        'IA', 'MT', 'NY', 'ID', 'VT', 'VA', 'TX', 'FL', 'CO', 'AZ', 'SC',
#        'NE', 'WY', 'HI', 'IL', 'NH', 'GA', 'AK', 'MD', 'AR', 'WI', 'OR',
#        'MI', 'DE', 'UT', 'CA', 'MN', 'SD', 'NC', 'WA', 'NM', 'NV', 'DC',
#        'KY', 'ME', 'MS', 'TN', 'PA', 'CT', 'ND'], dtype=object)

# %%
df['Account length'].unique()
# Out:
# array([128, 107, 137,  84,  75, 118, 121, 147, 117, 141,  65,  74, 168,
#         95,  62, 161,  85,  93,  76,  73,  77, 130, 111, 132, 174,  57,
#         54,  20,  49, 142, 172,  12,  72,  36,  78, 136, 149,  98, 135,
#         34, 160,  64,  59, 119,  97,  52,  60,  10,  96,  87,  81,  68,
#        125, 116,  38,  40,  43, 113, 126, 150, 138, 162,  90,  50,  82,
#        144,  46,  70,  55, 106,  94, 155,  80, 104,  99, 120, 108, 122,
#        157, 103,  63, 112,  41, 193,  61,  92, 131, 163,  91, 127, 110,
#        140,  83, 145,  56, 151, 139,   6, 115, 146, 185, 148,  32,  25,
#        179,  67,  19, 170, 164,  51, 208,  53, 105,  66,  86,  35,  88,
#        123,  45, 100, 215,  22,  33, 114,  24, 101, 143,  48,  71, 167,
#         89, 199, 166, 158, 196, 209,  16,  39, 173, 129,  44,  79,  31,
#        124,  37, 159, 194, 154,  21, 133, 224,  58,  11, 109, 102, 165,
#         18,  30, 176,  47, 190, 152,  26,  69, 186, 171,  28, 153, 169,
# ...

# %% [markdown]
# ## 2.5 Filtering on Rows

# %%
df.head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1            110.0
# 1                     26              161.6            123.0
# 2                      0              243.4            114.0
# 3                      0              299.4             71.0
# 4                      0              166.7            113.0
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4             99.0             16.78
# ...

# %%
# suppongo di volere solo i valori del dataframe in cui International plan sia == 'No'

# %%
df[df['International plan'] == 'No']
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                 No             Yes
# 1       OH             107        415                 No             Yes
# 2       NJ             137        415                 No              No
# 6       MA             121        510                 No             Yes
# 8       LA             117        408                 No              No
# ...    ...             ...        ...                ...             ...
# 3327    SC              79        415                 No              No
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
# posso aggiungere anche condizioni

# %%
df[(df['Account length'] > 100) & (df['Area code'] == 415)]
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                 No             Yes
# 1       OH             107        415                 No             Yes
# 2       NJ             137        415                 No              No
# 7       MO             147        415                Yes              No
# 9       WV             141        415                Yes             Yes
# ...    ...             ...        ...                ...             ...
# 3315    ME             149        415                 No             Yes
# 3317    SD             163        415                Yes              No
# 3323    IN             117        415                 No              No
# 3324    WV             159        415                 No              No
# 3328    AZ             192        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %% [markdown]
# ## 2.6 Indexing with iloc

# %%
# iloc mi fa accedere alle righe o colonne con il numero corrispondente 
# un solo valore dentro = voglio la riga numero (...)
# due valori dentro = voglio la riga numero(...) e la colonna numero(...)

# %%
df.iloc[14]
# Out:
# State                        IA
# Account length               62
# Area code                   415
# International plan           No
# Voice mail plan              No
# Number vmail messages         0
# Total day minutes           NaN
# Total day calls             NaN
# Total day charge            NaN
# Total eve minutes         307.2
# Total eve calls            76.0
# Total eve charge          26.11
# Total night minutes       203.0
# Total night calls          99.0
# Total night charge         9.14
# Total intl minutes         13.1
# Total intl calls              6
# Total intl charge          3.54
# Customer service calls      4.0
# Churn                     False
# Name: 14, dtype: object

# %%
# ad esempio, se volessi vedere lungo la colonna State (la prima) mi basta scrivere:

# %%
df.iloc[14, 0]
# Out:
# 'IA'

# %%
# posso anche fare slicing

# %%
df.iloc[11:22]
# Out:
#    State  Account length  Area code International plan Voice mail plan  \
# 11    RI              74        415                 No              No
# 12    IA             168        408                 No              No
# 13    MT              95        510                 No              No
# 14    IA              62        415                 No              No
# 15    NY             161        415                 No              No
# 16    ID              85        408                 No             Yes
# 17    VT              93        510                 No              No
# 18    VA              76        510                 No             Yes
# 19    TX              73        415                 No              No
# 20    FL             147        415                 No              No
# 21    CO              77        408                 No              No
#
#     Number vmail messages  Total day minutes  Total day calls  \
# ...

# %% [markdown]
# ## 2.7 Indexing with loc

# %%
# prima di tutto creo una copia del dataframe

# %%
state = df.copy()

# %%
data.head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1            110.0
# 1                     26              161.6            123.0
# 2                      0              243.4            114.0
# 3                      0              299.4             71.0
# 4                      0              166.7            113.0
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4             99.0             16.78
# ...

# %%
# per lavorare meglio, posso settare una colonna come indice e usare loc esattamente su quella

# %%
state.set_index('State', inplace = True)

# %%
state.head()
# Out:
#        Account length  Area code International plan Voice mail plan  \
# State
# KS                128        415                 No             Yes
# OH                107        415                 No             Yes
# NJ                137        415                 No              No
# OH                 84        408                Yes              No
# OK                 75        415                Yes              No
#
#        Number vmail messages  Total day minutes  Total day calls  \
# State
# KS                        25              265.1            110.0
# OH                        26              161.6            123.0
# NJ                         0              243.4            114.0
# OH                         0              299.4             71.0
# OK                         0              166.7            113.0
#
#        Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# State
# ...

# %%
state.loc['KS']
# Out:
#        Account length  Area code International plan Voice mail plan  \
# State
# KS                128        415                 No             Yes
# KS                 70        408                 No              No
# KS                 92        408                Yes              No
# KS                137        408                 No              No
# KS                132        415                 No              No
# ...               ...        ...                ...             ...
# KS                164        510                 No             Yes
# KS                101        415                 No              No
# KS                127        415                 No             Yes
# KS                 57        415                 No              No
# KS                170        415                 No             Yes
#
#        Number vmail messages  Total day minutes  Total day calls  \
# State
# KS                        25              265.1            110.0
# ...

# %% [markdown]
# # 3 Update

# %% [markdown]
# ## 3.1 Dropping rows

# %%
# con pandas voglio vedere quali colonne hanno dei valori nulli o NaN, in modo da toglierle e progredire più velocemente con i calcoli

# %%
df.isnull().sum()
# Out:
# State                      0
# Account length             0
# Area code                  0
# International plan         0
# Voice mail plan            0
# Number vmail messages      0
# Total day minutes         10
# Total day calls           10
# Total day charge          18
# Total eve minutes          9
# Total eve calls            8
# Total eve charge           0
# Total night minutes        0
# Total night calls          1
# Total night charge         0
# Total intl minutes         0
# Total intl calls           0
# Total intl charge          5
# Customer service calls     5
# Churn                      8
# dtype: int64

# %%
# elimino le colonne con valori mancanti

# %%
df.dropna(inplace = True)

# %%
df.isnull().sum()
# Out:
# State                     0
# Account length            0
# Area code                 0
# International plan        0
# Voice mail plan           0
# Number vmail messages     0
# Total day minutes         0
# Total day calls           0
# Total day charge          0
# Total eve minutes         0
# Total eve calls           0
# Total eve charge          0
# Total night minutes       0
# Total night calls         0
# Total night charge        0
# Total intl minutes        0
# Total intl calls          0
# Total intl charge         0
# Customer service calls    0
# Churn                     0
# dtype: int64

# %% [markdown]
# ## 3.2 Dropping columns

# %%
# stesso discorso ma con le colonne

# %%
df.drop('Area code', axis = 1) # axis mi dice se volgio droppare una riga (axis = 0) o colonna (axis = 1)
# Out:
#      State  Account length International plan Voice mail plan  \
# 0       KS             128                 No             Yes
# 1       OH             107                 No             Yes
# 2       NJ             137                 No              No
# 3       OH              84                Yes              No
# 4       OK              75                Yes              No
# ...    ...             ...                ...             ...
# 3328    AZ             192                 No             Yes
# 3329    WV              68                 No              No
# 3330    RI              28                 No              No
# 3331    CT             184                Yes              No
# 3332    TN              74                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 0                        25              265.1            110.0
# 1                        26              161.6            123.0
# ...

# %% [markdown]
# ## 3.3 Creare delle colonne con calcoli

# %%
# creo una colonna unendone due già esistenti
df['Nuova colonna'] = df['Total day minutes'] + df['Total day calls']

# %%
df.head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1            110.0
# 1                     26              161.6            123.0
# 2                      0              243.4            114.0
# 3                      0              299.4             71.0
# 4                      0              166.7            113.0
#
#    Total day charge  Total eve minutes  ...  Total eve charge  \
# 0             45.07              197.4  ...             16.78
# ...

# %%
# setto i valori come voglio io all'interno della colonna
df['Nuova colonna'] = 100

# %%
df.head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1            110.0
# 1                     26              161.6            123.0
# 2                      0              243.4            114.0
# 3                      0              299.4             71.0
# 4                      0              166.7            113.0
#
#    Total day charge  Total eve minutes  ...  Total eve charge  \
# 0             45.07              197.4  ...             16.78
# ...

# %% [markdown]
# ## 3.4 Aggiornare singolo valore

# %%
# voglio modificare un singolo valore, il primo della colonna nuova che ho creato in precedenza
df.iloc[0, -1] = 'Speraci'

# %%
df.head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1            110.0
# 1                     26              161.6            123.0
# 2                      0              243.4            114.0
# 3                      0              299.4             71.0
# 4                      0              166.7            113.0
#
#    Total day charge  Total eve minutes  ...  Total eve charge  \
# 0             45.07              197.4  ...             16.78
# ...

# %% [markdown]
# ## 3.5 Apply che modifica i valori nel dataframe

# %%
# situazione : volgio iterare sulla colonna Churn e voglio mmodificare i valori booleani in valori binari
# devo quindi filtrare e poi applicare la maschera al dataset
# creo una nuova colonna e applico una funzione lambda che fa esattamente questo
df['Churn Binario'] = df['Churn'].apply(lambda x : 1 if x == True else 0)

# %%
df[df['Churn'] == True].head()
# Out:
#    State  Account length  Area code International plan Voice mail plan  \
# 10    IN              65        415                 No              No
# 41    MD             135        408                Yes             Yes
# 48    ID             119        415                 No              No
# 54    WY              87        415                 No              No
# 57    CO             121        408                 No             Yes
#
#     Number vmail messages  Total day minutes  Total day calls  \
# 10                      0              129.1            137.0
# 41                     41              173.1             85.0
# 48                      0              159.1            114.0
# 54                      0              151.0             83.0
# 57                     30              198.4            129.0
#
#     Total day charge  Total eve minutes  ...  Total night minutes  \
# 10             21.95              228.5  ...                208.8
# ...

# %% [markdown]
# # 4 Cancellare e mandare in uscita i DataFrame

# %% [markdown]
# ## 4.1 Uscita in CSV

# %%
df.to_csv('file in csv.csv')

# %%
# lo vedrò nella repository di jupiter

# %% [markdown]
# ## 4.2 Uscita in JSON

# %%
df.to_json()

# %% [markdown]
# ## 4.3 Uscita in HTML

# %%
df.to_html()

# %% [markdown]
# ## 4.4 Cancellare un DataFrame

# %%
del df
